# %% [markdown]
# ## Importing libraries and data set

# %%
import pandas as pd
import numpy as np
import os

# %%
# To establish a path to 02 Data folder
path=r'C:\Users\Shelb\OneDrive\Documents\CF Coursework\Advanced Analytics and Dashboard Design\2022 WA State CAFV Project'

# %%
df_EV_title=pd.read_csv(os.path.join(path,'02 Data','Original Data','Electric Vehicle Title and Registration Activity.csv'))

# %% [markdown]
# ## Data exploration and descriptive statistics

# %%
# To show the size of the data set
df_EV_title.shape
# Out:
# (633874, 32)

# %%
# To show column names
df_EV_title.columns
# Out:
# Index(['Clean Alternative Fuel Vehicle Type', 'VIN (1-10)', 'Model Year',
#        'Make', 'Model', 'New or Used Vehicle', 'Sale Price',
#        'DOL Transaction Date', 'Transaction Type', 'Transaction Year',
#        'Electric Vehicle Fee Paid', 'County', 'City', 'Postal Code',
#        'Electric Range', 'Base MSRP', '2015 HB 2778 Exemption Eligibility',
#        'Sale Date', 'Vehicle Primary Use', 'State of Residence',
#        'DOL Vehicle ID', 'Legislative District',
#        '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Meets 2019 HB 2042 Electric Range Requirement',
#        'Meets 2019 HB 2042 Sale Date Requirement',
#        'Meets 2019 HB 2042 Sale Price/Value Requirement', 'Odometer Reading',
#        'Odometer Code', 'Transportation Electrification Fee Paid',
#        'Hybrid Vehicle Electrification Fee Paid', '2020 Census Tract',
#        'Electric Utility'],
#       dtype='object')

# %% [markdown]
# ##### -Column names will need to be reformated without spaces to work in Python

# %%
# To show data types for each column
df_EV_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633874 entries, 0 to 633873
# Data columns (total 32 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   Clean Alternative Fuel Vehicle Type                             633874 non-null  object
#  1   VIN (1-10)                                                      633874 non-null  object
#  2   Model Year                                                      633874 non-null  int64
#  3   Make                                                            633874 non-null  object
#  4   Model                                                           633835 non-null  object
#  5   New or Used Vehicle                                             633874 non-null  object
#  6   Sale Price                                                      633874 non-null  int64
# ...

# %%
# To show descriptive statistics
df_EV_title.describe()
# Out:
#           Model Year    Sale Price  Transaction Year    Postal Code  \
# count  633874.000000  6.338740e+05     633874.000000  633738.000000
# mean     2017.160292  9.946394e+03       2019.348770   98135.171885
# std         3.143883  3.086735e+04          2.524943    2651.645901
# min      1993.000000  0.000000e+00       2010.000000     745.000000
# 25%      2015.000000  0.000000e+00       2018.000000   98047.000000
# 50%      2017.000000  0.000000e+00       2020.000000   98117.000000
# 75%      2020.000000  0.000000e+00       2021.000000   98360.000000
# max      2023.000000  1.231202e+07       2022.000000   99901.000000
#
#        Electric Range      Base MSRP  DOL Vehicle ID  Legislative District  \
# count   633874.000000  633874.000000    6.338740e+05         631687.000000
# mean       103.809408    3387.680186    2.026291e+08             30.272035
# std         94.405468   14883.095252    1.040864e+08             14.703528
# ...

# %% [markdown]
# ##### -The data type for the Legislative District column should be changed from float64 to object as the information it holds is categorical and not quantitative.

# %%
# To remove the limit on how many columns python shows in df.head() and display the first 5 rows of the set
pd.set_option('display.max_columns', None)
df_EV_title.head()
# Out:
#   Clean Alternative Fuel Vehicle Type  VIN (1-10)  Model Year       Make  \
# 0      Battery Electric Vehicle (BEV)  7FCTGAAA8N        2022     RIVIAN
# 1      Battery Electric Vehicle (BEV)  5YJ3E1EBXN        2022      TESLA
# 2      Battery Electric Vehicle (BEV)  5YJ3E1EBXN        2022      TESLA
# 3      Battery Electric Vehicle (BEV)  1G1FX6S07H        2017  CHEVROLET
# 4      Battery Electric Vehicle (BEV)  1G1FX6S07H        2017  CHEVROLET
#
#      Model New or Used Vehicle  Sale Price DOL Transaction Date  \
# 0      R1T                 New           0       August 16 2022
# 1  Model 3                 New       70440      October 11 2022
# 2  Model 3                 New           0      October 11 2022
# 3  Bolt EV                Used       21219      October 15 2019
# 4  Bolt EV                Used           0      October 15 2019
#
#         Transaction Type  Transaction Year Electric Vehicle Fee Paid County  \
# ...

# %% [markdown]
# ##### -The 2015 HB 2778 Exemption Eligibility and 2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility columns contain both whether the vehicle is eligible or not, and in the event that it is not eligible the reasons why are listed. This should be split into separate columns to make the information useful for this analysis.

# %% [markdown]
# ##### - The 2020 Census Tract column is not necessary for this analysis

# %% [markdown]
# ## Reformatting column names and dropping unnecessary column

# %%
# To remove spaces from column names for use in Python
df_EV_title.rename(columns={'Clean Alternative Fuel Vehicle Type':'Clean_Alternative _Fuel _Vehicle _Type'},inplace=True)
df_EV_title.rename(columns={'VIN (1-10)':'VIN'},inplace=True)
df_EV_title.rename(columns={'Model Year':'Model_Year'},inplace=True)
df_EV_title.rename(columns={'New or Used Vehicle':'New_or_Used_Vehicle'},inplace=True)
df_EV_title.rename(columns={'Sale Price':'Sale_Price'},inplace=True)
df_EV_title.rename(columns={'DOL Transaction Date':'DOL_Transaction_Date'},inplace=True)
df_EV_title.rename(columns={'Transaction Type':'Transaction_Type'},inplace=True)
df_EV_title.rename(columns={'Transaction Year':'Transaction_Year'},inplace=True)
df_EV_title.rename(columns={'Electric Vehicle Fee Paid':'Electric_Vehicle_Fee_Paid'},inplace=True)
df_EV_title.rename(columns={'Postal Code':'Postal_Code'},inplace=True)

# %%
df_EV_title.rename(columns={'Electric Range':'Electric_Range'},inplace=True)
df_EV_title.rename(columns={'Base MSRP':'Base_MSRP'},inplace=True)
df_EV_title.rename(columns={'2015 HB 2778 Exemption Eligibility':'2015_HB_2778_Exemption_Eligibility'},inplace=True)
df_EV_title.rename(columns={'Sale Date':'Sale_Date'},inplace=True)
df_EV_title.rename(columns={'Vehicle Primary Use':'Vehicle_Primary_Use'},inplace=True)
df_EV_title.rename(columns={'State of Residence':'State_of_Residence'},inplace=True)
df_EV_title.rename(columns={'DOL Vehicle ID ':'DOL_Vehicle_ID'},inplace=True)
df_EV_title.rename(columns={'Legislative District':'Legislative_District'},inplace=True)
df_EV_title.rename(columns={'2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility':'2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility'},inplace=True)
df_EV_title.rename(columns={'Meets 2019 HB 2042 Electric Range Requirement':'Meets_2019_HB_2042_Electric_Range_Requirement'},inplace=True)

# %%
df_EV_title.rename(columns={'Meets 2019 HB 2042 Sale Date Requirement':'Meets_2019_HB_2042_Sale_Date_Requirement'},inplace=True)
df_EV_title.rename(columns={'Meets 2019 HB 2042 Sale Price/Value Requirement':'Meets_2019_HB_2042_Sale_Price/Value_Requirement'},inplace=True)
df_EV_title.rename(columns={'Odometer Reading':'Odometer_Reading'},inplace=True)
df_EV_title.rename(columns={'Odometer Code':'Odometer_Code'},inplace=True)
df_EV_title.rename(columns={'Transportation Electrification Fee Paid':'Transportation_Electrification_Fee_Paid'},inplace=True)
df_EV_title.rename(columns={'Hybrid Vehicle Electrification Fee Paid':'Hybrid_Vehicle_Electrification_Fee_Paid'},inplace=True)
df_EV_title.rename(columns={'2020 Census Tract':'2020_Census_Tract'},inplace=True)
df_EV_title.rename(columns={'Electric Utility':'Electric_Utility'},inplace=True)

# %%
# To confirm successful column name changes
df_EV_title.columns
# Out:
# Index(['Clean_Alternative _Fuel _Vehicle _Type', 'VIN', 'Model_Year', 'Make',
#        'Model', 'New_or_Used_Vehicle', 'Sale_Price', 'DOL_Transaction_Date',
#        'Transaction_Type', 'Transaction_Year', 'Electric_Vehicle_Fee_Paid',
#        'County', 'City', 'Postal_Code', 'Electric_Range', 'Base_MSRP',
#        '2015_HB_2778_Exemption_Eligibility', 'Sale_Date',
#        'Vehicle_Primary_Use', 'State_of_Residence', 'DOL Vehicle ID',
#        'Legislative_District',
#        '2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility',
#        'Meets_2019_HB_2042_Electric_Range_Requirement',
#        'Meets_2019_HB_2042_Sale_Date_Requirement',
#        'Meets_2019_HB_2042_Sale_Price/Value_Requirement', 'Odometer_Reading',
#        'Odometer_Code', 'Transportation_Electrification_Fee_Paid',
#        'Hybrid_Vehicle_Electrification_Fee_Paid', '2020_Census_Tract',
#        'Electric_Utility'],
#       dtype='object')

# %%
# To drop unnecessary 2020_Census_Tract column
df_EV_title=df_EV_title.drop(columns = ['2020_Census_Tract'])

# %% [markdown]
# ## Fixing columns with mixed data types

# %%
# To check for columns with mixed data types
for col in df_EV_title.columns.tolist():
  weird = (df_EV_title[[col]].applymap(type) != df_EV_title[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_EV_title[weird]) > 0:
    print (col)
# Out:
# Model
# County
# City
# Sale_Date
# State_of_Residence
# 2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility
# Transportation_Electrification_Fee_Paid
# Hybrid_Vehicle_Electrification_Fee_Paid
# Electric_Utility

# %%
# To change mixed data types to string
df_EV_title['Model']=df_EV_title['Model'].astype('str')
df_EV_title['County']=df_EV_title['County'].astype('str')
df_EV_title['City']=df_EV_title['City'].astype('str')
df_EV_title['Sale_Date']=df_EV_title['Sale_Date'].astype('str')
df_EV_title['State_of_Residence']=df_EV_title['State_of_Residence'].astype('str')
df_EV_title['2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility']=df_EV_title['2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility'].astype('str')
df_EV_title['Transportation_Electrification_Fee_Paid']=df_EV_title['Transportation_Electrification_Fee_Paid'].astype('str')
df_EV_title['Hybrid_Vehicle_Electrification_Fee_Paid']=df_EV_title['Hybrid_Vehicle_Electrification_Fee_Paid'].astype('str')
df_EV_title['Electric_Utility']=df_EV_title['Electric_Utility'].astype('str')

# %% [markdown]
# ## Finding and addressing missing values

# %%
# To find NaN missing values
df_EV_title.isnull().sum()
# Out:
# Clean_Alternative _Fuel _Vehicle _Type                               0
# VIN                                                                  0
# Model_Year                                                           0
# Make                                                                 0
# Model                                                                0
# New_or_Used_Vehicle                                                  0
# Sale_Price                                                           0
# DOL_Transaction_Date                                                 0
# Transaction_Type                                                     0
# Transaction_Year                                                     0
# Electric_Vehicle_Fee_Paid                                            0
# County                                                               0
# City                                                                 0
# ...

# %% [markdown]
# ##### There are 136 missing values in the Postal_Code column and 2187 missing values in the Legislative_District column

# %%
# To create a subset for NaN values in Postal_Code
df_nan_post_code=df_EV_title[df_EV_title['Postal_Code'].isnull()==True]
df_nan_post_code
# Out:
#         Clean_Alternative _Fuel _Vehicle _Type         VIN  Model_Year  \
# 11936   Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6E47F        2015
# 11937   Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6E47F        2015
# 11938   Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6E47F        2015
# 11939   Plug-in Hybrid Electric Vehicle (PHEV)  1G1RB6E47F        2015
# 55909           Battery Electric Vehicle (BEV)  5YJSA1E42G        2016
# ...                                        ...         ...         ...
# 606816  Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E4XE        2014
# 612848          Battery Electric Vehicle (BEV)  5YJXCBE27J        2018
# 613487  Plug-in Hybrid Electric Vehicle (PHEV)  5UXKT0C38H        2017
# 614652          Battery Electric Vehicle (BEV)  5YJSA1E24G        2016
# 614653          Battery Electric Vehicle (BEV)  5YJSA1E24G        2016
#
#              Make    Model New_or_Used_Vehicle  Sale_Price  \
# ...

# %% [markdown]
# ##### A number of records missing Postal_Code values are also missing city, county, and legislative district information. Many of these records are for EV buyers who reside outside of Washington state

# %%
# To look for records of buyers outside of Washington state
df_EV_title['State_of_Residence'].value_counts(dropna=False)
# Out:
# WA     631688
# CA        490
# VA        227
# TX        157
# OR        153
# MD        118
# FL         90
# AZ         74
# NV         59
# GA         59
# CO         51
# IL         50
# NY         49
# DC         38
# NC         37
# HI         35
# CT         33
# MA         32
# MI         32
# AK         29
# ID         27
# PA         27
# NJ         27
# MN         25
# SC         21
# UT         21
# TN         18
# OK         17
# IN         16
# MO         15
# MT         14
# NE         14
# OH         12
# LA         11
# AL         11
# NM         10
# KS         10
# NH         10
# AR          8
# KY          7
# BC          6
# MS          6
# RI          6
# WY          5
# WI          4
# ME          4
# ND          3
# DE          3
# XX          3
# AE          3
# PR          3
# SD          2
# ON          2
# QC          1
# nan         1
# Name: State_of_Residence, dtype: int64

# %%
# To create a flag for out of state buyers
result=[]

for value in df_EV_title['State_of_Residence']:
    if value == 'WA':
        result.append('Local_Resident')
    else:
        result.append('Out_of_State_Resident')

# %%
df_EV_title['Out_of_State_Buyer?']=result
df_EV_title['Out_of_State_Buyer?'].value_counts(dropna=False)
# Out:
# Local_Resident           631688
# Out_of_State_Resident      2186
# Name: Out_of_State_Buyer?, dtype: int64

# %% [markdown]
# ##### The number of out of state buyers accounts for both the missing values in the Postal_Code and Legislative_District columns

# %% [markdown]
# ## Finding and addressing duplicates

# %%
# To find duplicate records
df_duplicates=df_EV_title[df_EV_title.duplicated()]

# %%
df_duplicates
# Out:
#         Clean_Alternative _Fuel _Vehicle _Type         VIN  Model_Year  \
# 13958           Battery Electric Vehicle (BEV)  5YJSA1E27F        2015
# 52202           Battery Electric Vehicle (BEV)  5YJ3E1EB9L        2020
# 82296           Battery Electric Vehicle (BEV)  537LS7D49B        2011
# 112059          Battery Electric Vehicle (BEV)  5YJ3E1EB9K        2019
# 222591          Battery Electric Vehicle (BEV)  5YJSA1H12E        2014
# 269732  Plug-in Hybrid Electric Vehicle (PHEV)  WBY1Z8C52H        2017
# 272643  Plug-in Hybrid Electric Vehicle (PHEV)  SALWR4RY9M        2021
# 306932          Battery Electric Vehicle (BEV)  1G1FX6S0XJ        2018
# 328281          Battery Electric Vehicle (BEV)  1N4BZ0CP3H        2017
# 486270          Battery Electric Vehicle (BEV)  1N4AZ0CP6F        2015
# 562563  Plug-in Hybrid Electric Vehicle (PHEV)  LYVBR0DL8K        2019
# 590120  Plug-in Hybrid Electric Vehicle (PHEV)  JTDKN3DP3C        2012
#
# ...

# %%
# To check the shape of df_duplicates
df_duplicates.shape
# Out:
# (12, 32)

# %% [markdown]
# ##### There are 12 duplicate records

# %%
# To check the shape of df_EV_title
df_EV_title.shape
# Out:
# (633874, 32)

# %%
# To remove duplicates from the data set
df_EV_title_clean=df_EV_title.drop_duplicates()

# %%
# To check the new shape of the data set
df_EV_title_clean.shape
# Out:
# (633862, 32)

# %% [markdown]
# ##### Duplicates successfully removed

# %% [markdown]
# ## To address the useability 2015_HB_2778_Exemption_Eligibility and 2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility columns

# %%
# To count the values in 2015_HB_2778_Exemption_Eligibility
df_EV_title_clean['2015_HB_2778_Exemption_Eligibility'].value_counts()
# Out:
# TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                                                                           335810
# VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                             70974
# ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                                                   57677
# ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined                                                                                39805
# ...

# %% [markdown]
# ##### Clean Alternative Fuel Vehicle indicates eligibility for exemption
# ##### There seem to be three categories for non eligibility. Reasons for non eligibility listed are as follows:
#
# #### Transaction Not Eligible
# ##### --Non sale, registration transaction
# ##### --Sale before 7/15/2015
# ##### --Not a new vehicle
# ##### --Sale after 5/31/2018
#
# #### Vehicle Model Not Eligible
# ##### --Low battery range
# ##### --Base MSRP too high
#
# #### Cannot Determine Eligibility
# ##### --Base MSRP not determined
# ##### --No battery range

# %%
# To create a simplified column flagging 2015 HB 2778 eligibility
result=[]

for value in df_EV_title_clean['2015_HB_2778_Exemption_Eligibility']:
    if value == 'Clean Alternative Fuel Vehicle':
        result.append('Eligible')
    else:
        result.append('Not Eligible')

# %%
df_EV_title_clean['2015_HB_2778_Eligible?']=result
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\3396968791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Eligible?']=result

# %%
df_EV_title_clean['2015_HB_2778_Eligible?'].value_counts()
# Out:
# Not Eligible    632948
# Eligible           914
# Name: 2015_HB_2778_Eligible?, dtype: int64

# %%
# To change 2015_HB_2778_Eligible? to string data type
df_EV_title_clean['2015_HB_2778_Eligible?']=df_EV_title_clean['2015_HB_2778_Eligible?'].astype('str')
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\3346023776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Eligible?']=df_EV_title_clean['2015_HB_2778_Eligible?'].astype('str')

# %%
# To create a column for 2015 HB 2778 Transaction Eligibility
result=[]

for value in df_EV_title_clean['2015_HB_2778_Exemption_Eligibility']:
    if value == 'TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction':
        result.append('Transaction Not Eligible')
    elif value == 'ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction':
        result.append('Transaction Not Eligible')
    elif value == 'ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle':
        result.append('Transaction Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Transaction Not Eligible')
    else:
        result.append('Eligible Transaction')

# %%
df_EV_title_clean['2015_HB_2778_Transaction_Eligible?']=result
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\3137136193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Transaction_Eligible?']=result

# %%
df_EV_title_clean['2015_HB_2778_Transaction_Eligible?'].value_counts()
# Out:
# Transaction Not Eligible    614475
# Eligible Transaction         19387
# Name: 2015_HB_2778_Transaction_Eligible?, dtype: int64

# %%
# To change 2015_HB_2778_Transaction_Eligible? to string data type
df_EV_title_clean['2015_HB_2778_Transaction_Eligible?']=df_EV_title_clean['2015_HB_2778_Transaction_Eligible?'].astype('str')
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\3260150776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Transaction_Eligible?']=df_EV_title_clean['2015_HB_2778_Transaction_Eligible?'].astype('str')

# %%
# To create a column for 2015 HB 2778 Vehicle Model Eligibility
result=[]

for value in df_EV_title_clean['2015_HB_2778_Exemption_Eligibility']:
    if value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle':
        result.append('Model Not Eligible')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; VEHICLE MODEL NOT ELIGIBLE: Base MSRP is too high':
        result.append('Model Not Eligible')
    else:
        result.append('Eligible Vehicle Model')

# %%
df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?']=result
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\502675508.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?']=result

# %%
df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?'].value_counts()
# Out:
# Eligible Vehicle Model    535261
# Model Not Eligible         98601
# Name: 2015_HB_2778_Vehicle_Model_Eligibile?, dtype: int64

# %%
df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?']=df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?'].astype('str')
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\2396373170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?']=df_EV_title_clean['2015_HB_2778_Vehicle_Model_Eligibile?'].astype('str')

# %%
# To create a column for 2015 HB 2778 Missing Vehicle Information
result=[]

for value in df_EV_title_clean['2015_HB_2778_Exemption_Eligibility']:
    if value == 'ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined ':
        result.append('Cannot Determine Eligibility')
    elif value == 'TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Sale after 5/31/2018; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    elif value == 'TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined ':
        result.append('Cannot Determine Eligibility')
    elif value == 'VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Not a new vehicle; TRANSACTION NOT ELIGIBLE: Transaction before 7/15/2015; CANNOT DETERMINE ELIGIBILITY: Base MSRP has not been determined':
        result.append('Cannot Determine Eligibility')
    else:
        result.append('All Vehicle Information Present')

# %%
df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information']= result
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\3819807178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information']= result

# %%
df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information'].value_counts()
# Out:
# All Vehicle Information Present    513733
# Cannot Determine Eligibility       120129
# Name: 2015_HB_2778_Missing_Vehicle_Information, dtype: int64

# %%
df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information']=df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information'].astype('str')
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\1043441379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information']=df_EV_title_clean['2015_HB_2778_Missing_Vehicle_Information'].astype('str')

# %%
# To show value counts for the 2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility column
pd.set_option('display.max_rows', None)
df_EV_title_clean['2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility'].value_counts()
# Out:
# TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                                                                               335810
# VEHICLE MODEL NOT ELIGIBLE: Low battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                                 70974
# ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Non-sale, registration transaction                                                                                                                                       57677
# ERROR: No battery range; TRANSACTION NOT ELIGIBLE: Sale price too high                                                                                                                                                      34209
# ...

# %%
# To create a simplified column flagging 2019 HB 2042 Eligibility
result=[]

for value in df_EV_title_clean['2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility']:
    if value == 'Clean Alternative Fuel Vehicle':
        result.append('Eligible')
    else:
        result.append('Not Eligible')

# %%
df_EV_title_clean['2019_HB_2042_Eligible?']=result
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\2774926025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2019_HB_2042_Eligible?']=result

# %%
df_EV_title_clean['2019_HB_2042_Eligible?'].value_counts()
# Out:
# Not Eligible    612445
# Eligible         21417
# Name: 2019_HB_2042_Eligible?, dtype: int64

# %%
# To change 2019_HB_2042_Eligible? to string data type
df_EV_title_clean['2019_HB_2042_Eligible?']=df_EV_title_clean['2019_HB_2042_Eligible?'].astype('str')
# Out:
# C:\Users\Shelb\AppData\Local\Temp\ipykernel_19424\722584305.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_EV_title_clean['2019_HB_2042_Eligible?']=df_EV_title_clean['2019_HB_2042_Eligible?'].astype('str')

# %%
# To remove the unusable 2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility and 2015_HB_2778_Exemption_Eligibility from the cleaned data set
df_EV_title_clean=df_EV_title_clean.drop(columns = ['2019_HB_2042_Clean_Alternative_Fuel_Vehicle_(CAFV)_Eligibility','2015_HB_2778_Exemption_Eligibility'])

# %% [markdown]
# ## Exporting and saving

# %%
# To check the shape of the cleaned data set
df_EV_title_clean.shape
# Out:
# (633862, 35)

# %%
# To save and export as a CSV file
df_EV_title_clean.to_csv(os.path.join(path,'02 Data','Prepared Data','clean_EV_title_and_reg_activity_12_2022.csv'))
